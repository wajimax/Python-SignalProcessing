# %%
#!/usr/bin/env python
# vim:fileencoding=utf-8
import sys
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import matplotlib
import pandas as pd

#データセットの分割
from sklearn.model_selection import train_test_split

# %%
#深層学習ライブラリ
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import SimpleRNN
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using Theano backend.

# %%
#音楽ファイル
Music_file = './Input/01_Radio/NHKRadio.wav'
Music_noise_file = './Input/01_Radio/NHKRadio_whitenoise.wav'

MusicType = 'NHK Radio'
MusicFileName = 'NHKRadio'
NoiseType = 'Whitenoise'

# %%
# wavファイル読み込み
Music_wav, Music_fs = sf.read(Music_file)

# ステレオ2chの場合、モノラル音源に変換(左右の各音を2で割った音を足して作成．)
if(Music_wav.shape[1] == 1):
    Music_wavdata = Music_wav
    print(Music_wav.shape[1])
else:
    Music_wavdata = (0.5 * Music_wav[:, 1]) + (0.5 * Music_wav[:, 0])

# %%
# wavファイル読み込み
Music_whitenoise_wav, Music_whitenoise_fs = sf.read(Music_noise_file)

# ステレオ2chの場合、モノラル音源に変換(左右の各音を2で割った音を足して作成．)
if(Music_whitenoise_wav.shape[1] == 1):
    Music_whitenoise_wavdata = Music_whitenoise_wav
    print(Music_whitenoise_wav.shape[1])
else:
    Music_whitenoise_wavdata = (0.5 * Music_whitenoise_wav[:, 1]) + (0.5 * Music_whitenoise_wav[:, 0])

# %%
#時間軸(信号の場合はLength)
#x = range(300)
x = range(500)

#Y軸は信号データ
#y = Music_whitenoise_wavdata[:300]
y = Music_whitenoise_wavdata[:500]

#学習のフレーム
l = 150

#関数
#信号データと学習のフレームを使用
def make_dataset(y, l):
  data = []
  target = []
  for i in range(len(y)-l):
    data.append(y[i:i+l])
    target.append(y[i + l])
  return(data, target)

#関数呼び出しでデータセットを作成
(data, target) = make_dataset(y, l)

# %%
#1フレームのデータ
#data[0]
#len(data[0])
#len(data)
#target
#len(target)

# %%
#RNN用のデータセットを作成
#ここで3次元データセットを作成しなくてはならない
data = np.array(data).reshape(-1, l, 1)

# %%
num_neurons = 1
n_hidden = 200

model = Sequential()
model.add(SimpleRNN(n_hidden, batch_input_shape=(None, l, num_neurons), return_sequences=False))
model.add(Dense(num_neurons))
model.add(Activation('linear'))
optimizer = Adam(lr = 0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer)
#model.compile(loss="mean_squared_logarithmic_error", optimizer=optimizer)
#model.compile(loss="mean_absolute_percentage_error", optimizer=optimizer)
#model.compile(loss="cosine_similarity", optimizer=optimizer)
#model.compile(loss="mean_absolute_error", optimizer=optimizer)
#early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=20)
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=20)

# %%
#model.fit(data, target, batch_size=300, epochs=100, validation_split=0.1, callbacks=[early_stopping])
model.fit(data, target, batch_size=300, epochs=100, validation_split=0.1, callbacks=[early_stopping])
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# Train on 315 samples, validate on 35 samples
# Epoch 1/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.1536e-04 - val_loss: 0.0024
# Epoch 2/100
# 315/315 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0330
# Epoch 3/100
# 315/315 [==============================] - 1s 2ms/step - loss: 0.0318 - val_loss: 0.0020
# Epoch 4/100
# 315/315 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 1.3192e-04
# Epoch 5/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.1047e-04 - val_loss: 2.0007e-04
# Epoch 6/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6997e-04 - val_loss: 1.1074e-04
# Epoch 7/100
# 315/315 [==============================] - 0s 2ms/step - loss: 8.9267e-05 - val_loss: 3.8524e-05
# Epoch 8/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.7727e-05 - val_loss: 3.8224e-05
# Epoch 9/100
# 315/315 [==============================] - 1s 2ms/step - loss: 3.8793e-05 - val_loss: 7.9991e-05
# Epoch 10/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.6337e-05 - val_loss: 8.1990e-05
# Epoch 11/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.7424e-05 - val_loss: 4.0285e-05
# Epoch 12/100
# 315/315 [==============================] - 1s 2ms/step - loss: 4.0986e-05 - val_loss: 2.8562e-05
# Epoch 13/100
# 315/315 [==============================] - 0s 2ms/step - loss: 2.3976e-05 - val_loss: 6.0788e-05
# Epoch 14/100
# 315/315 [==============================] - 1s 2ms/step - loss: 5.0769e-05 - val_loss: 6.3547e-05
# Epoch 15/100
# 315/315 [==============================] - 1s 2ms/step - loss: 5.2245e-05 - val_loss: 3.2283e-05
# Epoch 16/100
# 315/315 [==============================] - 0s 2ms/step - loss: 2.5603e-05 - val_loss: 2.6428e-05
# Epoch 17/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.7689e-05 - val_loss: 4.1105e-05
# Epoch 18/100
# 315/315 [==============================] - 0s 2ms/step - loss: 4.5279e-05 - val_loss: 3.4535e-05
# Epoch 19/100
# 315/315 [==============================] - 1s 2ms/step - loss: 3.7142e-05 - val_loss: 2.2860e-05
# Epoch 20/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.1537e-05 - val_loss: 3.2866e-05
# Epoch 21/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.7264e-05 - val_loss: 4.1936e-05
# Epoch 22/100
# 315/315 [==============================] - 1s 2ms/step - loss: 3.4081e-05 - val_loss: 3.0642e-05
# Epoch 23/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.4670e-05 - val_loss: 2.1986e-05
# Epoch 24/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.0980e-05 - val_loss: 2.5452e-05
# Epoch 25/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.6899e-05 - val_loss: 2.4041e-05
# Epoch 26/100
# 315/315 [==============================] - 0s 2ms/step - loss: 2.4783e-05 - val_loss: 2.1593e-05
# Epoch 27/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.9832e-05 - val_loss: 2.6195e-05
# Epoch 28/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.1716e-05 - val_loss: 2.9076e-05
# Epoch 29/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.3549e-05 - val_loss: 2.4737e-05
# Epoch 30/100
# 315/315 [==============================] - 0s 1ms/step - loss: 2.0546e-05 - val_loss: 2.1257e-05
# Epoch 31/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.9347e-05 - val_loss: 2.1054e-05
# Epoch 32/100
# 315/315 [==============================] - 0s 1ms/step - loss: 2.0017e-05 - val_loss: 2.0864e-05
# Epoch 33/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.9523e-05 - val_loss: 2.0829e-05
# Epoch 34/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8933e-05 - val_loss: 2.1072e-05
# Epoch 35/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8649e-05 - val_loss: 2.1067e-05
# Epoch 36/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8492e-05 - val_loss: 2.0539e-05
# Epoch 37/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8516e-05 - val_loss: 2.0292e-05
# Epoch 38/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.8657e-05 - val_loss: 2.0162e-05
# Epoch 39/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8802e-05 - val_loss: 2.0063e-05
# Epoch 40/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8780e-05 - val_loss: 2.0164e-05
# Epoch 41/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7967e-05 - val_loss: 2.2107e-05
# Epoch 42/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8461e-05 - val_loss: 2.3629e-05
# Epoch 43/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.9244e-05 - val_loss: 2.1813e-05
# Epoch 44/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.8180e-05 - val_loss: 2.0038e-05
# Epoch 45/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7563e-05 - val_loss: 1.9594e-05
# Epoch 46/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7612e-05 - val_loss: 1.9537e-05
# Epoch 47/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7486e-05 - val_loss: 1.9866e-05
# Epoch 48/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7230e-05 - val_loss: 2.1497e-05
# Epoch 49/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7752e-05 - val_loss: 2.3186e-05
# Epoch 50/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8659e-05 - val_loss: 2.1279e-05
# Epoch 51/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7536e-05 - val_loss: 1.9357e-05
# Epoch 52/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6965e-05 - val_loss: 1.9030e-05
# Epoch 53/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.7278e-05 - val_loss: 1.9154e-05
# Epoch 54/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6835e-05 - val_loss: 2.0120e-05
# Epoch 55/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6795e-05 - val_loss: 1.9558e-05
# Epoch 56/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.6609e-05 - val_loss: 1.8912e-05
# Epoch 57/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.6545e-05 - val_loss: 1.8864e-05
# Epoch 58/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.6436e-05 - val_loss: 1.8847e-05
# Epoch 59/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6334e-05 - val_loss: 1.8716e-05
# Epoch 60/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6280e-05 - val_loss: 1.8950e-05
# Epoch 61/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6167e-05 - val_loss: 1.9301e-05
# Epoch 62/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.6107e-05 - val_loss: 1.8627e-05
# Epoch 63/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6030e-05 - val_loss: 1.8384e-05
# Epoch 64/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6081e-05 - val_loss: 1.8440e-05
# Epoch 65/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5951e-05 - val_loss: 1.8286e-05
# Epoch 66/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6015e-05 - val_loss: 1.8302e-05
# Epoch 67/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5869e-05 - val_loss: 1.8580e-05
# Epoch 68/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5644e-05 - val_loss: 1.8479e-05
# Epoch 69/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5615e-05 - val_loss: 1.8962e-05
# Epoch 70/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5515e-05 - val_loss: 2.0336e-05
# Epoch 71/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5955e-05 - val_loss: 1.9456e-05
# Epoch 72/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.5477e-05 - val_loss: 1.8155e-05
# Epoch 73/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5638e-05 - val_loss: 1.8090e-05
# Epoch 74/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5859e-05 - val_loss: 1.8212e-05
# Epoch 75/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.5244e-05 - val_loss: 1.8698e-05
# Epoch 76/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.5071e-05 - val_loss: 1.8937e-05
# Epoch 77/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5040e-05 - val_loss: 1.8431e-05
# Epoch 78/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4937e-05 - val_loss: 1.8321e-05
# Epoch 79/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4842e-05 - val_loss: 1.8902e-05
# Epoch 80/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4861e-05 - val_loss: 1.9458e-05
# Epoch 81/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5019e-05 - val_loss: 1.9450e-05
# Epoch 82/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.4958e-05 - val_loss: 1.8402e-05
# Epoch 83/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.4528e-05 - val_loss: 1.7959e-05
# Epoch 84/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6283e-05 - val_loss: 1.8618e-05
# Epoch 85/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.7414e-05 - val_loss: 1.7943e-05
# Epoch 86/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.4580e-05 - val_loss: 2.0957e-05
# Epoch 87/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5578e-05 - val_loss: 2.0038e-05
# Epoch 88/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.5074e-05 - val_loss: 1.7964e-05
# Epoch 89/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4341e-05 - val_loss: 1.7532e-05
# Epoch 90/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4463e-05 - val_loss: 1.7856e-05
# Epoch 91/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.4220e-05 - val_loss: 1.9488e-05
# Epoch 92/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.4691e-05 - val_loss: 2.0265e-05
# Epoch 93/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.5048e-05 - val_loss: 1.8473e-05
# Epoch 94/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.4254e-05 - val_loss: 1.7499e-05
# Epoch 95/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4151e-05 - val_loss: 1.7880e-05
# Epoch 96/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.4076e-05 - val_loss: 1.8143e-05
# Epoch 97/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.4018e-05 - val_loss: 1.7444e-05
# Epoch 98/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4051e-05 - val_loss: 1.7522e-05
# Epoch 99/100
# 315/315 [==============================] - 0s 1ms/step - loss: 1.3929e-05 - val_loss: 1.8968e-05
# Epoch 100/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4244e-05 - val_loss: 1.9887e-05

# %%
fig = plt.figure(1)

#検証ではノイズがないデータを使用すること
pred = model.predict(data)

#Y軸のラベル
Signal_Ylabel_str = MusicType + 'Signal' + NoiseType
RNN_Ylabel_str = 'RNN Pred' + 'Signal'

plt.figure(figsize=(15, 4))
plt.subplot(1, 2, 1)
plt.xlim(0, 500)
plt.plot(x, y, color='blue')
plt.xlabel('Original Signal ' + MusicType)
plt.ylabel(RNN_Ylabel_str)
 
plt.subplot(1, 2, 2)
plt.xlim(0, 500)
plt.plot(x[:l], y[:l], color='blue', label=Signal_Ylabel_str)
plt.plot(x[l:], pred, color='red', label=RNN_Ylabel_str, linestyle="dotted")
plt.xlabel('RNN Prediction of Acoustic Signal(' + MusicType + ')')
plt.legend(loc='lower left')

#plt.savefig
fig.set_tight_layout(True)
plt.savefig('./Output/RNN_Pred_Signal/RNN_' + NoiseType + '_' + MusicFileName + '.png')
plt.show()
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\matplotlib\font_manager.py:1333: UserWarning: findfont: Font family [u'IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#シグナル値
pd_y = pd.DataFrame(y[:l],columns=["Signal"])
pd_pred = pd.DataFrame(pred,columns=["Signal"])
pd_concat_y = pd.concat([pd_y,pd_pred], axis=0)
pd_concat_y = pd_concat_y.reset_index(drop=True)

#時間軸
pd_pandas_x = pd.DataFrame(range(500),columns=["Time"])

#信号配列
pd_concat_Signal = pd.concat([pd_pandas_x,pd_concat_y], axis=1)

#保存
pd_concat_Signal.to_csv('./Output/RNN_Pred_Signal/RNN_' + NoiseType + '_' + MusicFileName + '.csv')
pd_concat_Signal
# Out:
#      Time    Signal
# 0       0 -0.006042
# 1       1  0.002380
# 2       2 -0.007431
# 3       3 -0.008270
# 4       4  0.005203
# 5       5 -0.005539
# 6       6 -0.002670
# 7       7  0.008148
# 8       8  0.003479
# 9       9 -0.004089
# 10     10 -0.008972
# 11     11  0.003708
# 12     12  0.003220
# 13     13  0.005646
# 14     14  0.002441
# 15     15  0.005295
# 16     16 -0.000565
# 17     17 -0.002975
# 18     18  0.000015
# 19     19  0.005478
# 20     20  0.004318
# 21     21 -0.003448
# 22     22  0.000412
# 23     23 -0.001556
# 24     24  0.007675
# 25     25  0.006500
# 26     26  0.000854
# 27     27 -0.000565
# 28     28  0.001129
# 29     29  0.001480
# ..    ...       ...
# 470   470 -0.001211
# 471   471 -0.000290
# 472   472  0.002603
# 473   473  0.002614
# 474   474 -0.002507
# 475   475 -0.003098
# 476   476 -0.003560
# 477   477  0.002039
# 478   478 -0.000858
# 479   479 -0.001073
# 480   480  0.001878
# 481   481 -0.008234
# 482   482  0.001224
# 483   483 -0.001901
# 484   484 -0.002628
# 485   485  0.002747
# 486   486 -0.004690
# 487   487 -0.002208
# 488   488  0.000483
# 489   489  0.000599
# 490   490  0.005279
# 491   491  0.000536
# 492   492 -0.002003
# 493   493 -0.000853
# 494   494 -0.002994
# 495   495  0.000471
# 496   496 -0.004064
# 497   497 -0.003028
# 498   498 -0.002141
# 499   499 -0.001661
#
# [500 rows x 2 columns]
