# %%
#!/usr/bin/env python
# vim:fileencoding=utf-8
import sys
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import matplotlib
import pandas as pd

#データセットの分割
from sklearn.model_selection import train_test_split

# %%
#深層学習ライブラリ
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import SimpleRNN
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using Theano backend.

# %%
#音楽ファイル
Music_file = './Input/03_Classic/Classic.wav'
Music_noise_file = './Input/03_Classic/Classic_tpdfnoise.wav'

MusicType = 'Classic'
MusicFileName = 'Classic'
NoiseType = 'Tpdfnoise'

# %%
# wavファイル読み込み
Music_wav, Music_fs = sf.read(Music_file)

# ステレオ2chの場合、モノラル音源に変換(左右の各音を2で割った音を足して作成．)
if(Music_wav.shape[1] == 1):
    Music_wavdata = Music_wav
    print(Music_wav.shape[1])
else:
    Music_wavdata = (0.5 * Music_wav[:, 1]) + (0.5 * Music_wav[:, 0])

# %%
# wavファイル読み込み
Music_whitenoise_wav, Music_whitenoise_fs = sf.read(Music_noise_file)

# ステレオ2chの場合、モノラル音源に変換(左右の各音を2で割った音を足して作成．)
if(Music_whitenoise_wav.shape[1] == 1):
    Music_whitenoise_wavdata = Music_whitenoise_wav
    print(Music_whitenoise_wav.shape[1])
else:
    Music_whitenoise_wavdata = (0.5 * Music_whitenoise_wav[:, 1]) + (0.5 * Music_whitenoise_wav[:, 0])

# %%
#時間軸(信号の場合はLength)
#x = range(300)
x = range(500)

#Y軸は信号データ
#y = Music_whitenoise_wavdata[:300]
y = Music_whitenoise_wavdata[:500]

#学習のフレーム
l = 150

#関数
#信号データと学習のフレームを使用
def make_dataset(y, l):
  data = []
  target = []
  for i in range(len(y)-l):
    data.append(y[i:i+l])
    target.append(y[i + l])
  return(data, target)

#関数呼び出しでデータセットを作成
(data, target) = make_dataset(y, l)

# %%
#1フレームのデータ
#data[0]
#len(data[0])
#len(data)
#target
#len(target)

# %%
#RNN用のデータセットを作成
#ここで3次元データセットを作成しなくてはならない
data = np.array(data).reshape(-1, l, 1)

# %%
num_neurons = 1
n_hidden = 200

model = Sequential()
model.add(SimpleRNN(n_hidden, batch_input_shape=(None, l, num_neurons), return_sequences=False))
model.add(Dense(num_neurons))
model.add(Activation('linear'))
optimizer = Adam(lr = 0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer)
#model.compile(loss="mean_squared_logarithmic_error", optimizer=optimizer)
#model.compile(loss="mean_absolute_percentage_error", optimizer=optimizer)
#model.compile(loss="cosine_similarity", optimizer=optimizer)
#model.compile(loss="mean_absolute_error", optimizer=optimizer)
#early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=20)
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=20)

# %%
#model.fit(data, target, batch_size=300, epochs=100, validation_split=0.1, callbacks=[early_stopping])
model.fit(data, target, batch_size=300, epochs=100, validation_split=0.1, callbacks=[early_stopping])
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# Train on 315 samples, validate on 35 samples
# Epoch 1/100
# 315/315 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 4.7092e-05
# Epoch 2/100
# 315/315 [==============================] - 1s 2ms/step - loss: 6.0487e-05 - val_loss: 1.0357e-04
# Epoch 3/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0088e-04 - val_loss: 1.5166e-05
# Epoch 4/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.0730e-05 - val_loss: 2.4308e-05
# Epoch 5/100
# 315/315 [==============================] - 1s 2ms/step - loss: 2.4230e-05 - val_loss: 1.3778e-05
# Epoch 6/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8950e-05 - val_loss: 1.3576e-05
# Epoch 7/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.8002e-05 - val_loss: 1.8688e-05
# Epoch 8/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.9689e-05 - val_loss: 1.1497e-05
# Epoch 9/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.3870e-05 - val_loss: 1.3261e-05
# Epoch 10/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7410e-05 - val_loss: 1.0649e-05
# Epoch 11/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.3333e-05 - val_loss: 1.4041e-05
# Epoch 12/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5571e-05 - val_loss: 1.1518e-05
# Epoch 13/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5409e-05 - val_loss: 9.6497e-06
# Epoch 14/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.2831e-05 - val_loss: 1.3633e-05
# Epoch 15/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5095e-05 - val_loss: 1.1009e-05
# Epoch 16/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4609e-05 - val_loss: 1.1040e-05
# Epoch 17/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4336e-05 - val_loss: 1.3681e-05
# Epoch 18/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5102e-05 - val_loss: 9.9147e-06
# Epoch 19/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.1891e-05 - val_loss: 1.2143e-05
# Epoch 20/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5408e-05 - val_loss: 1.0439e-05
# Epoch 21/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.2433e-05 - val_loss: 1.3364e-05
# Epoch 22/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4642e-05 - val_loss: 9.2712e-06
# Epoch 23/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.1844e-05 - val_loss: 1.3302e-05
# Epoch 24/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4610e-05 - val_loss: 1.3615e-05
# Epoch 25/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.4371e-05 - val_loss: 1.3733e-05
# Epoch 26/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.6970e-05 - val_loss: 8.8567e-06
# Epoch 27/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0828e-05 - val_loss: 2.1543e-05
# Epoch 28/100
# 315/315 [==============================] - 0s 2ms/step - loss: 2.1607e-05 - val_loss: 9.2120e-06
# Epoch 29/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0852e-05 - val_loss: 1.4751e-05
# Epoch 30/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7536e-05 - val_loss: 1.0410e-05
# Epoch 31/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.2066e-05 - val_loss: 1.1414e-05
# Epoch 32/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.1993e-05 - val_loss: 1.6793e-05
# Epoch 33/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.9891e-05 - val_loss: 9.3697e-06
# Epoch 34/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.1428e-05 - val_loss: 1.7106e-05
# Epoch 35/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.7229e-05 - val_loss: 9.2445e-06
# Epoch 36/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0595e-05 - val_loss: 9.7429e-06
# Epoch 37/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.1725e-05 - val_loss: 9.0633e-06
# Epoch 38/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0173e-05 - val_loss: 1.2676e-05
# Epoch 39/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.3075e-05 - val_loss: 8.4530e-06
# Epoch 40/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.0150e-05 - val_loss: 1.1623e-05
# Epoch 41/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.3740e-05 - val_loss: 8.9640e-06
# Epoch 42/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.0246e-05 - val_loss: 9.2195e-06
# Epoch 43/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0015e-05 - val_loss: 1.1307e-05
# Epoch 44/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.3422e-05 - val_loss: 8.5162e-06
# Epoch 45/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.9414e-06 - val_loss: 1.3769e-05
# Epoch 46/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.4047e-05 - val_loss: 8.5065e-06
# Epoch 47/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.4622e-06 - val_loss: 1.3125e-05
# Epoch 48/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.5121e-05 - val_loss: 8.7161e-06
# Epoch 49/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0139e-05 - val_loss: 9.8665e-06
# Epoch 50/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0450e-05 - val_loss: 8.1666e-06
# Epoch 51/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.3079e-06 - val_loss: 8.3834e-06
# Epoch 52/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.4599e-06 - val_loss: 1.0021e-05
# Epoch 53/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0494e-05 - val_loss: 1.0504e-05
# Epoch 54/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0737e-05 - val_loss: 9.2063e-06
# Epoch 55/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0746e-05 - val_loss: 9.5936e-06
# Epoch 56/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0911e-05 - val_loss: 1.0265e-05
# Epoch 57/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0707e-05 - val_loss: 8.6726e-06
# Epoch 58/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.1041e-06 - val_loss: 1.1201e-05
# Epoch 59/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.2665e-05 - val_loss: 8.3245e-06
# Epoch 60/100
# 315/315 [==============================] - 0s 2ms/step - loss: 9.1607e-06 - val_loss: 1.3244e-05
# Epoch 61/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.3157e-05 - val_loss: 9.7668e-06
# Epoch 62/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.9096e-06 - val_loss: 9.6212e-06
# Epoch 63/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0697e-05 - val_loss: 7.9489e-06
# Epoch 64/100
# 315/315 [==============================] - 0s 2ms/step - loss: 8.6032e-06 - val_loss: 1.0559e-05
# Epoch 65/100
# 315/315 [==============================] - 0s 2ms/step - loss: 1.0352e-05 - val_loss: 8.3825e-06
# Epoch 66/100
# 315/315 [==============================] - 0s 2ms/step - loss: 9.0371e-06 - val_loss: 1.1860e-05
# Epoch 67/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.2781e-05 - val_loss: 8.2567e-06
# Epoch 68/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.5377e-06 - val_loss: 9.2755e-06
# Epoch 69/100
# 315/315 [==============================] - 0s 2ms/step - loss: 8.9702e-06 - val_loss: 8.6977e-06
# Epoch 70/100
# 315/315 [==============================] - 0s 2ms/step - loss: 8.9887e-06 - val_loss: 8.3544e-06
# Epoch 71/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.2462e-06 - val_loss: 1.0328e-05
# Epoch 72/100
# 315/315 [==============================] - 0s 2ms/step - loss: 9.4925e-06 - val_loss: 8.6196e-06
# Epoch 73/100
# 315/315 [==============================] - 0s 2ms/step - loss: 8.4894e-06 - val_loss: 9.2978e-06
# Epoch 74/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.0779e-06 - val_loss: 1.0189e-05
# Epoch 75/100
# 315/315 [==============================] - 0s 2ms/step - loss: 9.1183e-06 - val_loss: 1.1119e-05
# Epoch 76/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.7285e-06 - val_loss: 8.9721e-06
# Epoch 77/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.2894e-06 - val_loss: 9.0505e-06
# Epoch 78/100
# 315/315 [==============================] - 0s 2ms/step - loss: 8.0886e-06 - val_loss: 1.1912e-05
# Epoch 79/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0185e-05 - val_loss: 9.8320e-06
# Epoch 80/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.5571e-06 - val_loss: 9.1759e-06
# Epoch 81/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.3290e-06 - val_loss: 9.1996e-06
# Epoch 82/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.0429e-06 - val_loss: 9.0674e-06
# Epoch 83/100
# 315/315 [==============================] - 0s 1ms/step - loss: 7.9673e-06 - val_loss: 8.8452e-06

# %%
fig = plt.figure(1)

#検証ではノイズがないデータを使用すること
pred = model.predict(data)

#Y軸のラベル
Signal_Ylabel_str = MusicType + 'Signal' + NoiseType
RNN_Ylabel_str = 'RNN Pred' + 'Signal'

plt.figure(figsize=(15, 4))
plt.subplot(1, 2, 1)
plt.xlim(0, 500)
plt.plot(x, y, color='blue')
plt.xlabel('Original Signal ' + MusicType)
plt.ylabel(RNN_Ylabel_str)
 
plt.subplot(1, 2, 2)
plt.xlim(0, 500)
plt.plot(x[:l], y[:l], color='blue', label=Signal_Ylabel_str)
plt.plot(x[l:], pred, color='red', label=RNN_Ylabel_str, linestyle="dotted")
plt.xlabel('RNN Prediction of Acoustic Signal(' + MusicType + ')')
plt.legend(loc='lower left')

#plt.savefig
fig.set_tight_layout(True)
plt.savefig('./Output/RNN_Pred_Signal/RNN_' + NoiseType + '_' + MusicFileName + '.png')
plt.show()
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\matplotlib\font_manager.py:1333: UserWarning: findfont: Font family [u'IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#シグナル値
pd_y = pd.DataFrame(y[:l],columns=["Signal"])
pd_pred = pd.DataFrame(pred,columns=["Signal"])
pd_concat_y = pd.concat([pd_y,pd_pred], axis=0)
pd_concat_y = pd_concat_y.reset_index(drop=True)

#時間軸
pd_pandas_x = pd.DataFrame(range(500),columns=["Time"])

#信号配列
pd_concat_Signal = pd.concat([pd_pandas_x,pd_concat_y], axis=1)

#保存
pd_concat_Signal.to_csv('./Output/RNN_Pred_Signal/RNN_' + NoiseType + '_' + MusicFileName + '.csv')
pd_concat_Signal
# Out:
#      Time    Signal
# 0       0  0.001114
# 1       1 -0.004288
# 2       2 -0.003754
# 3       3  0.000793
# 4       4 -0.001038
# 5       5  0.000443
# 6       6 -0.001511
# 7       7  0.001297
# 8       8 -0.002579
# 9       9 -0.006027
# 10     10 -0.002182
# 11     11 -0.001129
# 12     12  0.001282
# 13     13  0.000397
# 14     14 -0.002396
# 15     15 -0.000076
# 16     16 -0.002808
# 17     17  0.002945
# 18     18 -0.002579
# 19     19 -0.000809
# 20     20 -0.002579
# 21     21  0.002502
# 22     22  0.001907
# 23     23  0.003525
# 24     24  0.003601
# 25     25  0.001663
# 26     26 -0.000610
# 27     27 -0.004272
# 28     28 -0.004593
# 29     29 -0.001816
# ..    ...       ...
# 470   470 -0.002680
# 471   471  0.000811
# 472   472  0.001935
# 473   473  0.000998
# 474   474 -0.000525
# 475   475  0.002114
# 476   476  0.000681
# 477   477  0.000616
# 478   478  0.004597
# 479   479  0.000514
# 480   480  0.001827
# 481   481 -0.001431
# 482   482 -0.000889
# 483   483  0.001523
# 484   484  0.001516
# 485   485  0.005907
# 486   486  0.002466
# 487   487 -0.000280
# 488   488 -0.000039
# 489   489  0.001455
# 490   490  0.000006
# 491   491  0.001338
# 492   492 -0.001673
# 493   493 -0.000482
# 494   494  0.002732
# 495   495 -0.000587
# 496   496  0.002840
# 497   497  0.001274
# 498   498 -0.001758
# 499   499  0.000313
#
# [500 rows x 2 columns]
