# %%
#!/usr/bin/env python
# vim:fileencoding=utf-8
import sys
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import matplotlib
import pandas as pd

#データセットの分割
from sklearn.model_selection import train_test_split

# %%
#深層学習ライブラリ
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import SimpleRNN
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using Theano backend.

# %%
#音楽ファイル
Music_file = './Input/01_Radio/NHKRadio.wav'
Music_noise_file = './Input/01_Radio/NHKRadio_brownnoise.wav'

MusicType = 'NHK Radio'
MusicFileName = 'NHKRadio'
NoiseType = 'Brownnoise'

# %%
# wavファイル読み込み
Music_wav, Music_fs = sf.read(Music_file)

# ステレオ2chの場合、モノラル音源に変換(左右の各音を2で割った音を足して作成．)
if(Music_wav.shape[1] == 1):
    Music_wavdata = Music_wav
    print(Music_wav.shape[1])
else:
    Music_wavdata = (0.5 * Music_wav[:, 1]) + (0.5 * Music_wav[:, 0])

# %%
# wavファイル読み込み
Music_whitenoise_wav, Music_whitenoise_fs = sf.read(Music_noise_file)

# ステレオ2chの場合、モノラル音源に変換(左右の各音を2で割った音を足して作成．)
if(Music_whitenoise_wav.shape[1] == 1):
    Music_whitenoise_wavdata = Music_whitenoise_wav
    print(Music_whitenoise_wav.shape[1])
else:
    Music_whitenoise_wavdata = (0.5 * Music_whitenoise_wav[:, 1]) + (0.5 * Music_whitenoise_wav[:, 0])

# %%
#時間軸(信号の場合はLength)
#x = range(300)
x = range(500)

#Y軸は信号データ
#y = Music_whitenoise_wavdata[:300]
y = Music_whitenoise_wavdata[:500]

#学習のフレーム
l = 150

#関数
#信号データと学習のフレームを使用
def make_dataset(y, l):
  data = []
  target = []
  for i in range(len(y)-l):
    data.append(y[i:i+l])
    target.append(y[i + l])
  return(data, target)

#関数呼び出しでデータセットを作成
(data, target) = make_dataset(y, l)

# %%
#1フレームのデータ
#data[0]
#len(data[0])
#len(data)
#target
#len(target)

# %%
#RNN用のデータセットを作成
#ここで3次元データセットを作成しなくてはならない
data = np.array(data).reshape(-1, l, 1)

# %%
num_neurons = 1
n_hidden = 200

model = Sequential()
model.add(SimpleRNN(n_hidden, batch_input_shape=(None, l, num_neurons), return_sequences=False))
model.add(Dense(num_neurons))
model.add(Activation('linear'))
optimizer = Adam(lr = 0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer)
#model.compile(loss="mean_squared_logarithmic_error", optimizer=optimizer)
#model.compile(loss="mean_absolute_percentage_error", optimizer=optimizer)
#model.compile(loss="cosine_similarity", optimizer=optimizer)
#model.compile(loss="mean_absolute_error", optimizer=optimizer)
#early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=20)
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=20)
# Out:
# INFO (theano.gof.compilelock): Waiting for existing lock by process '10816' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '9856' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '8724' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir

# %%
#model.fit(data, target, batch_size=300, epochs=100, validation_split=0.1, callbacks=[early_stopping])
model.fit(data, target, batch_size=300, epochs=100, validation_split=0.1, callbacks=[early_stopping])
# Out:
# INFO (theano.gof.compilelock): Waiting for existing lock by process '10816' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '7036' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '7036' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '7020' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '10980' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '7020' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '8232' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# INFO (theano.gof.compilelock): Waiting for existing lock by process '10212' (I am process '6764')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\AdminUser\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.13-64\lock_dir
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# Train on 315 samples, validate on 35 samples
# Epoch 1/100
# 315/315 [==============================] - 2s 7ms/step - loss: 1.4127e-05 - val_loss: 0.0025
# Epoch 2/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0060 - val_loss: 0.0367
# Epoch 3/100
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0361 - val_loss: 0.0558
# Epoch 4/100
# 315/315 [==============================] - 5s 17ms/step - loss: 0.0571 - val_loss: 2.1552e-04
# Epoch 5/100
# 315/315 [==============================] - 12s 37ms/step - loss: 0.0020 - val_loss: 9.8960e-04
# Epoch 6/100
# 315/315 [==============================] - 13s 40ms/step - loss: 0.0037 - val_loss: 0.2432
# Epoch 7/100
# 315/315 [==============================] - 5s 17ms/step - loss: 0.2305 - val_loss: 4.7800e-04
# Epoch 8/100
# 315/315 [==============================] - 5s 16ms/step - loss: 0.0045 - val_loss: 0.0234
# Epoch 9/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0311 - val_loss: 0.1799
# Epoch 10/100
# 315/315 [==============================] - 8s 25ms/step - loss: 0.1698 - val_loss: 0.0427
# Epoch 11/100
# 315/315 [==============================] - 5s 17ms/step - loss: 0.0413 - val_loss: 0.0035
# Epoch 12/100
# 315/315 [==============================] - 6s 19ms/step - loss: 0.0036 - val_loss: 0.0483
# Epoch 13/100
# 315/315 [==============================] - 7s 21ms/step - loss: 0.0499 - val_loss: 0.0092
# Epoch 14/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.0097 - val_loss: 0.0253
# Epoch 15/100
# 315/315 [==============================] - 11s 35ms/step - loss: 0.0244 - val_loss: 0.0165
# Epoch 16/100
# 315/315 [==============================] - 6s 20ms/step - loss: 0.0147 - val_loss: 0.0071
# Epoch 17/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0085 - val_loss: 0.0154
# Epoch 18/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0158 - val_loss: 0.0014
# Epoch 19/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0015 - val_loss: 0.0140
# Epoch 20/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0127 - val_loss: 1.2917e-04
# Epoch 21/100
# 315/315 [==============================] - 5s 16ms/step - loss: 2.1725e-04 - val_loss: 0.0076
# Epoch 22/100
# 315/315 [==============================] - 5s 15ms/step - loss: 0.0083 - val_loss: 7.0812e-04
# Epoch 23/100
# 315/315 [==============================] - 4s 14ms/step - loss: 9.5251e-04 - val_loss: 0.0050
# Epoch 24/100
# 315/315 [==============================] - 11s 34ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 25/100
# 315/315 [==============================] - 4s 13ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 26/100
# 315/315 [==============================] - 4s 14ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 27/100
# 315/315 [==============================] - 5s 14ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 28/100
# 315/315 [==============================] - 3s 11ms/step - loss: 8.8683e-04 - val_loss: 0.0021
# Epoch 29/100
# 315/315 [==============================] - 10s 33ms/step - loss: 0.0016 - val_loss: 1.5717e-04
# Epoch 30/100
# 315/315 [==============================] - 4s 11ms/step - loss: 3.3808e-04 - val_loss: 0.0010
# Epoch 31/100
# 315/315 [==============================] - 3s 9ms/step - loss: 0.0013 - val_loss: 1.8745e-04
# Epoch 32/100
# 315/315 [==============================] - 8s 27ms/step - loss: 1.2348e-04 - val_loss: 0.0013
# Epoch 33/100
# 315/315 [==============================] - 2s 5ms/step - loss: 9.5135e-04 - val_loss: 9.1288e-07
# Epoch 34/100
# 315/315 [==============================] - 8s 24ms/step - loss: 4.8357e-05 - val_loss: 4.7186e-04
# Epoch 35/100
# 315/315 [==============================] - 4s 12ms/step - loss: 6.6159e-04 - val_loss: 5.1791e-05
# Epoch 36/100
# 315/315 [==============================] - 5s 17ms/step - loss: 2.5613e-05 - val_loss: 6.9107e-04
# Epoch 37/100
# 315/315 [==============================] - 5s 15ms/step - loss: 4.7132e-04 - val_loss: 6.1468e-06
# Epoch 38/100
# 315/315 [==============================] - 6s 18ms/step - loss: 1.8857e-05 - val_loss: 1.9282e-04
# Epoch 39/100
# 315/315 [==============================] - 4s 12ms/step - loss: 3.2571e-04 - val_loss: 4.1011e-05
# Epoch 40/100
# 315/315 [==============================] - 2s 5ms/step - loss: 1.6653e-05 - val_loss: 3.3557e-04
# Epoch 41/100
# 315/315 [==============================] - 1s 5ms/step - loss: 1.9279e-04 - val_loss: 2.1723e-06
# Epoch 42/100
# 315/315 [==============================] - 2s 5ms/step - loss: 1.9711e-05 - val_loss: 4.3999e-05
# Epoch 43/100
# 315/315 [==============================] - 2s 5ms/step - loss: 1.1905e-04 - val_loss: 6.8505e-05
# Epoch 44/100
# 315/315 [==============================] - 2s 5ms/step - loss: 2.3096e-05 - val_loss: 1.5975e-04
# Epoch 45/100
# 315/315 [==============================] - 2s 5ms/step - loss: 7.0115e-05 - val_loss: 8.0512e-07
# Epoch 46/100
# 315/315 [==============================] - 2s 5ms/step - loss: 2.5972e-05 - val_loss: 4.3244e-06
# Epoch 47/100
# 315/315 [==============================] - 2s 5ms/step - loss: 4.1077e-05 - val_loss: 8.6906e-05
# Epoch 48/100
# 315/315 [==============================] - 1s 3ms/step - loss: 3.0416e-05 - val_loss: 7.2726e-05
# Epoch 49/100
# 315/315 [==============================] - 7s 22ms/step - loss: 2.0896e-05 - val_loss: 2.0727e-06
# Epoch 50/100
# 315/315 [==============================] - 1s 2ms/step - loss: 3.4654e-05 - val_loss: 4.9232e-06
# Epoch 51/100
# 315/315 [==============================] - 1s 2ms/step - loss: 1.0334e-05 - val_loss: 7.8355e-05
# Epoch 52/100
# 315/315 [==============================] - 1s 3ms/step - loss: 2.4172e-05 - val_loss: 1.7480e-05
# Epoch 53/100
# 315/315 [==============================] - 1s 2ms/step - loss: 5.0104e-06 - val_loss: 8.0344e-07
# Epoch 54/100
# 315/315 [==============================] - 1s 3ms/step - loss: 2.3558e-05 - val_loss: 2.6087e-05
# Epoch 55/100
# 315/315 [==============================] - 4s 14ms/step - loss: 5.5257e-06 - val_loss: 5.3325e-05
# Epoch 56/100
# 315/315 [==============================] - 7s 22ms/step - loss: 1.2738e-05 - val_loss: 7.9691e-06
# Epoch 57/100
# 315/315 [==============================] - 1s 2ms/step - loss: 7.5175e-06 - val_loss: 4.7651e-06
# Epoch 58/100
# 315/315 [==============================] - 1s 2ms/step - loss: 9.8194e-06 - val_loss: 3.9059e-05
# Epoch 59/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.1679e-06 - val_loss: 3.6048e-05
# Epoch 60/100
# 315/315 [==============================] - 1s 2ms/step - loss: 7.0508e-06 - val_loss: 6.2442e-06
# Epoch 61/100
# 315/315 [==============================] - 1s 2ms/step - loss: 8.6456e-06 - val_loss: 2.0349e-05
# Epoch 62/100
# 315/315 [==============================] - 1s 2ms/step - loss: 4.9175e-06 - val_loss: 3.9487e-05
# Epoch 63/100
# 315/315 [==============================] - 4s 13ms/step - loss: 8.1555e-06 - val_loss: 1.4400e-05
# Epoch 64/100
# 315/315 [==============================] - 6s 19ms/step - loss: 5.0238e-06 - val_loss: 8.4731e-06
# Epoch 65/100
# 315/315 [==============================] - 4s 11ms/step - loss: 6.9763e-06 - val_loss: 2.3836e-05
# Epoch 66/100
# 315/315 [==============================] - 1s 2ms/step - loss: 4.8646e-06 - val_loss: 3.5450e-05
# Epoch 67/100
# 315/315 [==============================] - 1s 2ms/step - loss: 6.9389e-06 - val_loss: 1.3283e-05
# Epoch 68/100
# 315/315 [==============================] - 1s 3ms/step - loss: 5.3700e-06 - val_loss: 1.5709e-05
# Epoch 69/100
# 315/315 [==============================] - 1s 2ms/step - loss: 5.0136e-06 - val_loss: 2.3662e-05
# Epoch 70/100
# 315/315 [==============================] - 1s 3ms/step - loss: 4.7689e-06 - val_loss: 1.0139e-05
# Epoch 71/100
# 315/315 [==============================] - 1s 2ms/step - loss: 6.2363e-06 - val_loss: 1.6107e-05
# Epoch 72/100
# 315/315 [==============================] - 1s 2ms/step - loss: 4.7213e-06 - val_loss: 3.7270e-05
# Epoch 73/100
# 315/315 [==============================] - 1s 2ms/step - loss: 7.4901e-06 - val_loss: 1.8222e-05

# %%
fig = plt.figure(1)

#検証ではノイズがないデータを使用すること
pred = model.predict(data)

#Y軸のラベル
Signal_Ylabel_str = MusicType + 'Signal' + NoiseType
RNN_Ylabel_str = 'RNN Pred' + 'Signal'

plt.figure(figsize=(15, 4))
plt.subplot(1, 2, 1)
plt.xlim(0, 500)
plt.plot(x, y, color='blue')
plt.xlabel('Original Signal ' + MusicType)
plt.ylabel(RNN_Ylabel_str)
 
plt.subplot(1, 2, 2)
plt.xlim(0, 500)
plt.plot(x[:l], y[:l], color='blue', label=Signal_Ylabel_str)
plt.plot(x[l:], pred, color='red', label=RNN_Ylabel_str, linestyle="dotted")
plt.xlabel('RNN Prediction of Acoustic Signal(' + MusicType + ')')
plt.legend(loc='lower left')

#plt.savefig
fig.set_tight_layout(True)
plt.savefig('./Output/RNN_Pred_Signal/RNN_' + NoiseType + '_' + MusicFileName + '.png')
plt.show()
# Out:
# C:\Users\AdminUser\Anaconda2\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\AdminUser\Anaconda2\lib\site-packages\matplotlib\font_manager.py:1333: UserWarning: findfont: Font family [u'IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#シグナル値
pd_y = pd.DataFrame(y[:l],columns=["Signal"])
pd_pred = pd.DataFrame(pred,columns=["Signal"])
pd_concat_y = pd.concat([pd_y,pd_pred], axis=0)
pd_concat_y = pd_concat_y.reset_index(drop=True)

#時間軸
pd_pandas_x = pd.DataFrame(range(500),columns=["Time"])

#信号配列
pd_concat_Signal = pd.concat([pd_pandas_x,pd_concat_y], axis=1)

#保存
pd_concat_Signal.to_csv('./Output/RNN_Pred_Signal/RNN_' + NoiseType + '_' + MusicFileName + '.csv')
pd_concat_Signal
# Out:
#      Time    Signal
# 0       0  0.000229
# 1       1  0.000183
# 2       2 -0.000183
# 3       3 -0.000412
# 4       4 -0.000320
# 5       5 -0.000336
# 6       6 -0.000565
# 7       7  0.000015
# 8       8 -0.000092
# 9       9 -0.000046
# 10     10  0.000031
# 11     11 -0.000122
# 12     12 -0.000290
# 13     13 -0.000061
# 14     14 -0.000153
# 15     15 -0.000183
# 16     16  0.000122
# 17     17 -0.000137
# 18     18 -0.000366
# 19     19 -0.000137
# 20     20  0.000336
# 21     21  0.000198
# 22     22 -0.000198
# 23     23 -0.000381
# 24     24 -0.000015
# 25     25  0.000153
# 26     26  0.000519
# 27     27  0.000229
# 28     28  0.000534
# 29     29  0.000397
# ..    ...       ...
# 470   470 -0.000814
# 471   471 -0.000815
# 472   472 -0.000826
# 473   473 -0.000809
# 474   474 -0.000809
# 475   475 -0.000817
# 476   476 -0.000816
# 477   477 -0.000806
# 478   478 -0.000822
# 479   479 -0.000819
# 480   480 -0.000806
# 481   481 -0.000811
# 482   482 -0.000801
# 483   483 -0.000807
# 484   484 -0.000794
# 485   485 -0.000798
# 486   486 -0.000813
# 487   487 -0.000832
# 488   488 -0.000825
# 489   489 -0.000827
# 490   490 -0.000830
# 491   491 -0.000859
# 492   492 -0.000850
# 493   493 -0.000855
# 494   494 -0.000853
# 495   495 -0.000854
# 496   496 -0.000866
# 497   497 -0.000864
# 498   498 -0.000855
# 499   499 -0.000867
#
# [500 rows x 2 columns]
